# %% [markdown]
# # Handling ABC Articles

# %%
from unstructured.partition.auto import partition
from unstructured.documents.elements import *
from unstructured.staging.weaviate import create_unstructured_weaviate_class, stage_for_weaviate

import weaviate
from weaviate.util import generate_uuid5

from dotenv import load_dotenv
import os
import json
from datetime import date
import tqdm
load_dotenv()
# Out:
# True

# %%
weaviate_url = os.getenv("WEAVIATE_URL")
weaviate_api_key = os.getenv("WEAVIATE_API_KEY")
openai_api_key=os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ## Weaviate schemas
# Schemas are patterns for data. The template that exists is a good base but this layer is ripe for customization.
#
# Allowing user input here can assist with searching later on. The recommendation engine can use tags to help put useful information in front of me. Auto-ingesting data could also use tags for reliable sources (e.g. #media)
#
# A blank text box (upload note - i like the name reverie) which would be useful for experimenting and curating a database.

# %% [markdown]
# What follows is the definition a generalized 'unstructured document' class for Weaviate. Once this is working, next step is to make one for a specific use-case, e.g. abc online articles.

# %%
article_url = "https://www.abc.net.au/news/2023-07-11/australian-renters-mould-exposure-impacting-mental-health/102563872?sf267830207=1"
import requests
from unstructured.partition.auto import partition
from unstructured.staging.weaviate import stage_for_weaviate
from unstructured.partition.html import partition_html

# Fetch data from URL
html_content = requests.get(article_url).text


# Assuming html_content is the HTML content you got from the URL
elements = partition_html(text=html_content)
data_objects = stage_for_weaviate(elements)

# %%
data_objects
# Out:
# [{'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Renters more likely than owner-occupiers to face health risks from house quality, expert says',
#   'category': 'UncategorizedText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'ABC RN',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'By Sam Nichols for The Money',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Posted',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'ABC News: Jack Fisher)',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Help keep family & friends informed by sharing this article',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'abc.net.au/news/australian-renters-mould-exposure-impacting-mental-health/102563872',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Link copied',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Copy link',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'When 28-year-old Shay moved to Sydney late last year, she was warned that finding a rental would be incredibly competitive\xa0and would take time.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Both predictions came true.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '"I would have seen maybe 50 [properties]," she tells ABC RN\'s The Money.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'ABC RN: Sophie Kesteven)',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'For\xa0weeks Shay and her housemate inspected properties, many of which were charging "an extreme price" but "weren\'t worth it" because they were decrepit or covered in mould.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '"And nine times out of 10, when it was advertised as two-bedroom, it was actually one bedroom with an additional corner of the house that, at best, could fit a desk or cot."',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'It was so competitive that, despite offering to pay higher-than-listed prices for two rental properties, she was still unable to secure a home.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Listen\xa0to the podcast',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'The Money explains how the Australian economy and everything in it works, and how it connects to the global economy.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "It's a familiar story\xa0in a rental climate that has\xa0many Australians struggling to find a home. Some data shows\xa0that rental stress has never been higher.",
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "But Shay's story reveals another side to the rental crisis.",
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'When she eventually secured a rental property in inner-city Sydney, she quickly noticed problems.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Defective light switches near a stairwell led to her housemate "fall[ing] down the stairs at night and smack[ing] his head through the wall".',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Then, black mould began to appear throughout the house.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "Shay's landlord addressed the mould after she complained, but her experience highlights an overlooked\xa0feature of Australia's rental crisis: its physical and psychological impacts on tenants.",
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'ABC RN: Sophie Kesteven)',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Mould more common in rentals',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "Rebecca Bentley is the director of the National Health and Medical Research Council's (NHMRC) Centre of Research Excellence in Healthy Housing. She's\xa0researched a number of health concerns in the current renting environment.",
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "One of them, as in Shay's case, is mould exposure.",
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "According to Professor\xa0Bentley's work, the prevalence of mould is more common in Australia's rental homes than in owner-occupied homes, which tend to have better maintenance and are more likely\xa0to comply with building standards.",
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '"On average, about 34 per cent of homes across Australia report some kind of mould or damp in their homes, but it\'s much greater for people who are renting," Professor\xa0Bentley says.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '"If we look at people in public housing in New South Wales, it looks like around 60 per cent of people are reporting some kind of problem with their home in terms of mould or damp."',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'ABC News: Jack Fisher)',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Professor Bentley says direct mould exposure has been shown to exacerbate existing respiratory conditions\xa0like asthma.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "But that's not the extent of the problem.",
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '"We know that that\'s just a small fraction of the way in which exposure to mould or people\'s housing conditions are impacting on their health," Professor\xa0Bentley says.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'She says other chronic respiratory illnesses could be affected, too.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "Plus, there's significant financial impact.",
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "Professor Bentley says she's\xa0calculated that if mould exposure alone\xa0was addressed, Australia could save $1.35 billion in healthcare expenditure and gain $7.5 billion in productivity.",
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'An overall hit to sense of wellbeing',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Another health risk of the rental crisis, according to Professor Bentley, is to mental wellbeing.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Housing problems found to negatively affect our mental healthAustralian researchers say housing affordability directly and indirectly affect our mental health.Read more',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '"Just the experience of financial hardship\xa0and stress that\'s associated with being in unaffordable rental housing impacts household budgets. It impacts people\'s stress levels and sense of wellbeing," she says.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "Research has long reported how financial instability can worsen someone's mental health.",
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Professor Bentley says that\'s partly because when people are paying more than they can afford, it "gives a sense of lack of control over where people are going to be living".',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '"So people may be paying too much for their housing, but they don\'t have another option."',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Supplied:\xa0Alina Golovachenko)',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'This feeling\xa0can then be compounded by things like no-cause evictions\xa0or repairs going ignored by landlords.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Lack of protections',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Research\xa0has estimated that 1.1 million Australians are living in poor housing conditions. In 2018, it was reported that more than half of Australian renters were living in a home that needed repairs.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "Australian homes falling below WHO's recommended 'safe' temperatureResearchers are finding links between cold homes and\xa0the occupants' physical and mental health.Read more",
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Renters who find themselves in such a home\xa0can file complaints to their relative civil and administrative tribunal or terminate their lease if a landlord is not meeting their contractual obligations.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'But while landlords do have obligations to complete repairs, there are reported cases of tenants being unwilling to flag repairs over fears of retaliation.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Leo Patterson Ross,\xa0spokesperson for the National Association of Tenant Organisations,\xa0says renters need better legislation to protect them.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "He says Australia has laws and protections for renters regarding repairs, but\xa0what's missing is the ability to enforce\xa0these laws.",
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '"Unlike other essential services, there is no third party coming in and checking that the property is actually fit for habitation.\xa0It\'s up to the tenant," he says.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '"If you\'re a tenant who is being rejected from 100 properties already, is facing sleeping in the car or sleeping in really unsafe environments, you might well accept that a property is [unsafe or unfit] for habitation, because the alternatives are much worse."',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Supplied: LinkedIn)',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Patterson Ross says another problem for tenants is the "very individualised" way rental laws are structured,\xa0leaving\xa0the onus on renters to pursue the tenancy breaches against a landlord.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '"That has a couple of ramifications for repairs," he says.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '"The main one is that once a tenant moves out of the property — even if it was in awful condition — there is now no longer a legal obligation on the owner to do anything about that property."',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'More stories from The Money:',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "Will Netflix be the Australian film and television industry's lifeline?",
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'A shortage of this metal could be a disaster for the transition to renewables',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Online sports betting is targeting young Australians. These academics want more to be done to protect them',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'What is inflationary psychology and how is it impacting our rising cost of living?',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'This creates an environment where renters may be harmed by\xa0moving into homes that are of substandard quality\xa0and who are then\xa0then left to chase their landlord to ensure that the repairs are completed.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '"For a lot of owners, they will just do the repair," Patterson Ross says.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '"The challenge for renters is that you don\'t know until it\'s too late.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '"You don\'t know if your owner is going to do the repairs or not, or how hard you\'re going to have to push to get it done."',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'All of which, he says, points very clearly towards the need for change, in order to minimise the psychological and physical health risks for renters.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Because in the current environment, "very clearly there is harm being caused", he says.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'RN in your inbox',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Get more stories that go beyond the news cycle with our weekly newsletter.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Your information is being handled in accordance with the ',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'ABC Privacy Collection Statement.',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Posted',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Share',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Copy link',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Facebook',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Twitter',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Related Stories',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "'Designed as winter tents': Why are Australian homes so cold in the winter?",
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "Some of us are more vulnerable to mould allergies than others. Here's what symptoms to look out for",
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "Bedrooms the size of closets, no repairs and a lot of mould: Welcome to Sydney's nightmare rental market",
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "David's house was 'so unhealthy no person could occupy it', but he lived in it for three years",
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'As soon as Joanne moved into her brand new townhouse, the problems started',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'More on:',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Byron Bay',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Cost of Living',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Economic Trends',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Housing Construction Industry',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Housing Market',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Interest Rates',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Laws',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Melbourne',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Mental Health',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Property Prices',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Public Housing',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Rental Housing',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Respiratory Diseases',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Sydney',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'If you need someone to talk to, call:',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Lifeline on 13 11 14',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Kids Helpline on 1800 551 800',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'MensLine Australia on 1300 789 978',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Suicide Call Back Service on 1300 659 467',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Beyond Blue on 1300 22 46 36',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Headspace on 1800 650 890',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'QLife on 1800 184 527',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Top Stories',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Review announced into delivery of gender-affirming care in NSW following 4C investigation',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Ben Roberts-Smith to appeal after losing landmark defamation case',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Minister indicates Australia could follow UK and force banks to reimburse scam victims',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "'You're talking about some people paying 3 or 4 per cent more on their mortgage ... overnight'",
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'NSW high school student dies weeks after contracting influenza',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Mining company agrees to record payout after admitting to draining millions of litres from Sydney water supply',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Family of great-grandmother who died after allegedly being tasered by police sues NSW',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "Teenage killers of Queensland 15-year-old suffered 'miscarriage of justice' and will be retried, court rules",
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "New data reveals Russia's 'hidden' death toll in Ukraine war",
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "'Absolutely emotional': Sydney man freed from Vietnam prison and returned to Australia",
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "Why has Australia signed up to Germany's Climate Club and what difference will it make?",
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Three brothers own the NZ volcano that killed 17 Australians. Today their trial begins',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "'The theft was rife': Craig Kelly in court over federal campaign poster dispute",
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Sexual abuse survivor suing government, sporting organisation, after abuse by paedophile nurse',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Magistrate refuses bail for NSW man charged with murdering ex-wife in car crash',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Popular Now',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '1.',
#   'category': 'UncategorizedText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Ben Roberts-Smith to appeal after losing landmark defamation case',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '2.',
#   'category': 'UncategorizedText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "New data reveals Russia's 'hidden' death toll in Ukraine war",
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '3.',
#   'category': 'UncategorizedText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "Teenage killers of Queensland 15-year-old suffered 'miscarriage of justice' and will be retried, court rules",
#   'category': 'UncategorizedText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '4.',
#   'category': 'UncategorizedText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'NSW high school student dies weeks after contracting influenza',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '5.',
#   'category': 'UncategorizedText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Family of great-grandmother who died after allegedly being tasered by police sues NSW',
#   'category': 'UncategorizedText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '6.',
#   'category': 'UncategorizedText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Mining company agrees to record payout after admitting to draining millions of litres from Sydney water supply',
#   'category': 'UncategorizedText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Top Stories',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Review announced into delivery of gender-affirming care in NSW following 4C investigation',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Ben Roberts-Smith to appeal after losing landmark defamation case',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Minister indicates Australia could follow UK and force banks to reimburse scam victims',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "'You're talking about some people paying 3 or 4 per cent more on their mortgage ... overnight'",
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'NSW high school student dies weeks after contracting influenza',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Mining company agrees to record payout after admitting to draining millions of litres from Sydney water supply',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Family of great-grandmother who died after allegedly being tasered by police sues NSW',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "Teenage killers of Queensland 15-year-old suffered 'miscarriage of justice' and will be retried, court rules",
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "New data reveals Russia's 'hidden' death toll in Ukraine war",
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Just In',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "Teenager overheard saying he 'would do something' at Anzac service next year, court told19m ago19 minutes agoTue 11 Jul 2023 at 5:14am",
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "Rare penguins' Aussie arrival not a good sign, researcher says26m ago26 minutes agoTue 11 Jul 2023 at 5:07am",
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Ben Roberts-Smith to appeal after losing landmark defamation case29m ago29 minutes agoTue 11 Jul 2023 at 5:05am',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "'Why the empty plinth?': Colonial statue removal to be explained, but some still not happy at 'cancelling'29m ago29 minutes agoTue 11 Jul 2023 at 5:04am",
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "'The theft was rife': Craig Kelly in court over federal campaign poster dispute30m ago30 minutes agoTue 11 Jul 2023 at 5:03am",
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "New data reveals Russia's 'hidden' death toll in Ukraine war35m ago35 minutes agoTue 11 Jul 2023 at 4:59am",
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'More Just In',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Back to top',
#   'category': 'NarrativeText'}]

# %%
abc_class = {
    'class': 'ABCNewsArticle',
    'description': 'Class for ABC News articles',
    'properties': [
        {'name': 'text', 'dataType': ['text']},
        {'name': 'category', 'dataType': ['text']},
        {'name': 'article_name', 'dataType': ['text']},
        {'name': 'date', 'dataType': ['text']},
        {'name': 'url', 'dataType': ['text']},
        {'name': 'tags', 'dataType': ['text']},
        {'name': 'upload_note', 'dataType': ['text']},
    ],
    'vectorizer': 'text2vec-openai', 
    "moduleConfig": {
        "text2vec-openai": {
            "vectorizeClassName": False
        }
    },

}


client = weaviate.Client(
    url=weaviate_url,
    auth_client_secret=weaviate.AuthApiKey(api_key=weaviate_api_key),
    additional_headers= {
        "X-OpenAI-Api-Key": openai_api_key,
    }
)

# %% [markdown]
# ## Modifying the schema
# Below code blocks are used to update the schema in Weaviate. Don't need to run this every time.

# %% [markdown]
# ### Create schema with the defined classes

# %%
schema = {"classes": [unstructured_class]}
# add the ABCNewsArticle class to the schema
schema["classes"].append(abc_class)
client.schema.create(schema)

# %% [markdown]
# ### Print defined schemas

# %%
schema = {"classes": [abc_class]}

print(schema)
client.schema.create(schema)
# Out:
# {'classes': [{'class': 'ABCNewsArticle', 'description': 'Class for ABC News articles', 'properties': [{'name': 'text', 'dataType': ['text']}, {'name': 'category', 'dataType': ['text']}, {'name': 'article_name', 'dataType': ['text']}, {'name': 'date', 'dataType': ['text']}, {'name': 'url', 'dataType': ['text']}, {'name': 'tags', 'dataType': ['text']}, {'name': 'upload_note', 'dataType': ['text']}], 'vectorizer': 'text2vec-openai', 'moduleConfig': {'text2vec-openai': {'vectorizeClassName': False}}}]}

# %% [markdown]
# ### Delete all classes in schema

# %%
schema = client.schema.get()

for class_info in schema['classes']:
    class_name = class_info['class']
    client.schema.delete_class(class_name)

# %% [markdown]
# ### Show properties of the first class in the schema

# %%
schema = client.schema.get()
schema['classes'][1]
# Out:
# {'class': 'ABCNewsArticle',
#  'description': 'Class for ABC News articles',
#  'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#   'cleanupIntervalSeconds': 60,
#   'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#  'moduleConfig': {'text2vec-openai': {'model': 'ada',
#    'modelVersion': '002',
#    'type': 'text',
#    'vectorizeClassName': False}},
#  'properties': [{'dataType': ['text'],
#    'indexFilterable': True,
#    'indexSearchable': True,
#    'moduleConfig': {'text2vec-openai': {'skip': False,
#      'vectorizePropertyName': False}},
#    'name': 'text',
#    'tokenization': 'word'},
#   {'dataType': ['text'],
#    'indexFilterable': True,
#    'indexSearchable': True,
#    'moduleConfig': {'text2vec-openai': {'skip': False,
#      'vectorizePropertyName': False}},
#    'name': 'category',
#    'tokenization': 'word'},
#   {'dataType': ['text'],
#    'indexFilterable': True,
#    'indexSearchable': True,
#    'moduleConfig': {'text2vec-openai': {'skip': False,
#      'vectorizePropertyName': False}},
#    'name': 'article_name',
#    'tokenization': 'word'},
#   {'dataType': ['text'],
#    'indexFilterable': True,
#    'indexSearchable': True,
#    'moduleConfig': {'text2vec-openai': {'skip': False,
#      'vectorizePropertyName': False}},
#    'name': 'date',
#    'tokenization': 'word'},
#   {'dataType': ['text'],
#    'indexFilterable': True,
#    'indexSearchable': True,
#    'moduleConfig': {'text2vec-openai': {'skip': False,
#      'vectorizePropertyName': False}},
#    'name': 'url',
#    'tokenization': 'word'},
#   {'dataType': ['text'],
#    'indexFilterable': True,
#    'indexSearchable': True,
#    'moduleConfig': {'text2vec-openai': {'skip': False,
#      'vectorizePropertyName': False}},
#    'name': 'tags',
#    'tokenization': 'word'},
#   {'dataType': ['text'],
#    'indexFilterable': True,
#    'indexSearchable': True,
#    'moduleConfig': {'text2vec-openai': {'skip': False,
#      'vectorizePropertyName': False}},
#    'name': 'upload_note',
#    'tokenization': 'word'}],
#  'replicationConfig': {'factor': 1},
#  'shardingConfig': {'virtualPerPhysical': 128,
#   'desiredCount': 1,
#   'actualCount': 1,
#   'desiredVirtualCount': 128,
#   'actualVirtualCount': 128,
#   'key': '_id',
#   'strategy': 'hash',
#   'function': 'murmur3'},
#  'vectorIndexConfig': {'skip': False,
#   'cleanupIntervalSeconds': 300,
#   'maxConnections': 64,
#   'efConstruction': 128,
#   'ef': -1,
#   'dynamicEfMin': 100,
#   'dynamicEfMax': 500,
#   'dynamicEfFactor': 8,
#   'vectorCacheMaxObjects': 1000000000000,
#   'flatSearchCutoff': 40000,
#   'distance': 'cosine',
#   'pq': {'enabled': False,
#    'bitCompression': False,
#    'segments': 0,
#    'centroids': 256,
#    'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}}},
#  'vectorIndexType': 'hnsw',
#  'vectorizer': 'text2vec-openai'}

# %% [markdown]
# ## Ingest document data using Unstructured
# Unstructured allows essentially any file to be uploaded and text data extracted. Testing on documents in `../data/`.

# %%
doc_elements = partition("../data/Politics and the English Language - George Orwell.pdf")
data_objects = stage_for_weaviate(doc_elements)

for key in ['filename', 'file_directory', 'filetype', 'page_number', 'text', 'category']:
    print("{0}: {1}".format(key, data_objects[0][key]))
# Out:
# filename: Politics and the English Language - George Orwell.pdf
# file_directory: ../data
# filetype: application/pdf
# page_number: 1
# text: Politics and the English Language - George Orwell
# category: Title

# %%
data_objects[0].keys()
# Out:
# dict_keys(['filetype', 'page_number', 'text', 'category'])

# %% [markdown]
# Not sure how much of the above data actually needs to be stored. Store it all for now, but there's likely more interesting metadata to be added here. Examples might be a sentiment analysis score, GPT-generated summary, external links and internal links, etc.
#
# Upload to Weaviate with the uploaded data fitting the defined schema:

# %%
# show the first data object of UncategorizedTest 
data_objects[0]['text']
# Out:
# 'Renters more likely than owner-occupiers to face health risks from house quality, expert says'

# %%
upload_note = "hello weaviate"
tags = "test, weaviate, python"


with client.batch(batch_size=10) as batch:
    for i, d in enumerate(data_objects):  
        properties = {
            'category': d['category'],
            'text': d['text'],
            'article_name' : data_objects[0]['text'],
            'url': article_url,
            'filetype': d['filetype'],
            'date': date.today().strftime("%Y-%m-%d"),
            'upload_note': upload_note, # testing
            'tags': tags # testing
        }
        batch.add_data_object(
            properties,
            'ABCNewsArticle',
            uuid=generate_uuid5(properties),
        )

# %% [markdown]
# ## Querying Weaviate
# Once the data is in Weaviate, a NearText search (to research) can be performed to find concepts similar to user input:

# %%
nearText = {"concepts": ["renters", "cost of living"]}

client = weaviate.Client(
    url=weaviate_url,
    auth_client_secret=weaviate.AuthApiKey(api_key=weaviate_api_key),
    additional_headers= {
        "X-OpenAI-Api-Key": openai_api_key,
    }
)


response = (
    client.query  # start a new query
    .get("ABCNewsArticle", ["text", "article_name", "upload_note", "tags"])  # get objects of the "UnstructuredDocument" class and retrieve their "text" property
    .with_near_text(nearText)  # find objects that are semantically similar to the text in "nearText"
    .with_limit(6)  # limit the results to the top 2 most similar objects
    #.with_where({
    #    "path": ["tags"],
    #    "operator": "Equal",
    #    "valueString": "updatedtest"
    #})
    .do()  # execute the query
)

# %%
# extract text from response
for i, r in enumerate(response['data']['Get']['ABCNewsArticle']):
    print("{0}: \nupload note: {1}\ntags: {2}\n{3}\n"
    .format(i+1, r['upload_note'], r['tags'], r['text'][:100] + '...'))
# Out:
# 1:
# upload note: hello weaviate
# tags: test, weaviate, python
# Cost of Living...
#
# 2:
# upload note: hello weaviate
# tags: test, weaviate, python
# What is inflationary psychology and how is it impacting our rising cost of living?...
#
# 3:
# upload note: hello weaviate
# tags: test, weaviate, python
# 'You're talking about some people paying 3 or 4 per cent more on their mortgage ... overnight'...
#
# 4:
# upload note: hello weaviate
# tags: test, weaviate, python
# 'You're talking about some people paying 3 or 4 per cent more on their mortgage ... overnight'...
#
# 5:
# upload note: hello weaviate
# tags: test, weaviate, python
# Professor Bentley says that's partly because when people are paying more than they can afford, it "g...
#
# 6:
# upload note: hello weaviate
# tags: test, weaviate, python
# "Just the experience of financial hardship and stress that's associated with being in unaffordable r...
