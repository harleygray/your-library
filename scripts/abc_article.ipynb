# %% [markdown]
# # Handling ABC Articles

# %%
from unstructured.partition.auto import partition
from unstructured.documents.elements import *
from unstructured.staging.weaviate import create_unstructured_weaviate_class, stage_for_weaviate

import weaviate
from weaviate.util import generate_uuid5

from dotenv import load_dotenv
import os
import json
from datetime import date
import tqdm
load_dotenv()
# Out:
# True

# %%
weaviate_url = os.getenv("WEAVIATE_URL")
weaviate_api_key = os.getenv("WEAVIATE_API_KEY")
openai_api_key=os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ## Weaviate schemas
# Schemas are patterns for data. The template that exists is a good base but this layer is ripe for customization.
#
# Allowing user input here can assist with searching later on. The recommendation engine can use tags to help put useful information in front of me. Auto-ingesting data could also use tags for reliable sources (e.g. #media)
#
# A blank text box (upload note - i like the name reverie) which would be useful for experimenting and curating a database.

# %% [markdown]
# What follows is the definition a generalized 'unstructured document' class for Weaviate. Once this is working, next step is to make one for a specific use-case, e.g. abc online articles.

# %%
article_url = "https://www.abc.net.au/news/2023-07-07/nt-2023-naidoc-parade-in-darwin/102576316"
import requests
from unstructured.partition.auto import partition
from unstructured.staging.weaviate import stage_for_weaviate
from unstructured.partition.html import partition_html

# Fetch data from URL
html_content = requests.get(article_url).text


# Assuming html_content is the HTML content you got from the URL
elements = partition_html(text=html_content)
data_objects = stage_for_weaviate(elements)

# %%
# show the text content of all data_objects with its category
for i, d in enumerate(data_objects):
    print("{0}: {1}".format(d['category'], d['text']))
# Out:
# Title: Thousands take to streets for 2023 NAIDOC parade in Darwin CBD
# Title: By Kyle Dowling
# Title: Posted
# Title: ABC News: Kyle Dowling)
# NarrativeText: Help keep family & friends informed by sharing this article
# Title: abc.net.au/news/nt-2023-naidoc-parade-in-darwin/102576316
# NarrativeText: Link copied
# Title: Copy link
# NarrativeText: Thousands of people have taken to the streets of Darwin CBD for a NAIDOC parade that saw leaders rally for a Yes vote in the upcoming referendum on an Indigenous Voice to Parliament.
# Title: Key points:
# ListItem: Larrakia Nation renewed calls for a treaty with the Northern Territory government
# ListItem: The peak body for Aboriginal organisations says a Voice to Parliament is "a way forward"
# ListItem: This year's NAIDOC theme is For Our Elders
# NarrativeText: The city saw one of the largest turnouts in recent years as people marched through the streets calling for respect for elders, and highlighting the desire for treaty.
# NarrativeText: Jerome Cubillo, the chair of Larrakia Nation — the peak body for traditional owners in the area — acknowledged previous work towards treaty and called for governments to take steps forward once again.
# NarrativeText: "We want to continue to hold our politicians accountable to say, 'We had momentum for a treaty in the Northern Territory. Where has that momentum gone? Where has that bravery gone?'"
# NarrativeText: "So we stand here, again, calling on the Northern Territory government to work with us [and] find a way … to get a treaty process back up," Mr Cubillo said.
# NarrativeText: "[It's the] only way to make our mob stronger, to give our mob a better future."
# NarrativeText: The event also focused on the upcoming Voice to Parliament referendum.
# Title: ABC News: Kyle Dowling)
# NarrativeText: John Paterson, a spokesperson for the Aboriginal Peak Organisations of the Northern Territory (APONT), said it was a way forward for First Nations Australians.
# NarrativeText: "With a Voice, we will be able to speak up and be heard for our families, our communities, our country and for elders," he said.
# NarrativeText: "Bring Aboriginal leadership and Aboriginal voices into policymaking is the only way to make our mob stronger, to give our mob a better future."
# Title: Read more about the Indigenous Voice to Parliament:
# ListItem: What is the Voice to Parliament and how would it work? Here's a complete breakdown
# ListItem: Here's what 11 First Nations MPs and senators think of a Voice to Parliament
# UncategorizedText: Northern Territory Aboriginal Affairs Minister Selena Uibo stressed the significance of the referendum.
# Title: ABC News: Kyle Dowling)
# NarrativeText: "Eight per cent of Australia's population will decide for the 2 per cent of us," she said.
# NarrativeText: "They'll determine the fate of Aboriginal and Torres Strait Islander futures.
# NarrativeText: "Our fate will be decided by one of two words: no or yes.
# NarrativeText: "We cannot wait another 56 years to have a voice on our own affairs."
# Title: Loading...
# Title: A time for solidarity, elders, and future generations
# NarrativeText: This year's NAIDOC theme is "For Our Elders" and is about recognising the importance of past generations and their journey and fight for the rights of First Nations people.
# NarrativeText: Michael McMahon, who has lived in Darwin for decades, said for him, this year's event was incredibly important.
# NarrativeText: "[Elders] helped us to shape our futures, and then for future generations to come," he said.
# NarrativeText: "I'm really looking forward to being a part of that and to seeing the younger, younger generation come through as well."
# Title: ABC News: Kyle Dowling)
# NarrativeText: NAIDOC Week brings together not only Aboriginal and Torres Strait Islander groups but also the wider Australian community.
# NarrativeText: For those who attended the march, this unity is essential.
# NarrativeText: "It's really important for all of our mobs, especially everyone from different mobs — you've got people from different states, different towns, different communities coming together — and we're all celebrating NAIDOC Week," Darwin resident Ayesha Kay said.
# NarrativeText: For Darren Griffon, this coming together is what NAIDOC is all about.
# Title: ABC News: Kyle Dowling)
# NarrativeText: "The main reason is to be united as one, to get together, show support for everybody," he said.
# NarrativeText: "Different tribes, you know, we've got a lot of diversity and tribes and that, so to come together, it's really good."
# Title: Loading...
# Title: Posted
# Title: Share
# ListItem: Copy link
# ListItem: Facebook
# ListItem: Twitter
# ListItem:
# Title: Related Stories
# ListItem: Damien has travelled Australia talking to communities about the Voice. Here's what he found
# ListItem: It began with some chords strummed around a camp fire before becoming an Australian music legacy
# Title: More on:
# ListItem: Aboriginal
# ListItem: Darwin
# ListItem: Indigenous (Aboriginal and Torres Strait Islander)
# ListItem: Indigenous Culture
# ListItem: Indigenous Policy
# Title: Top Stories
# ListItem: Is Michele Bullock the right choice as RBA governor? The experts are divided
# ListItem: Michele Bullock becomes first woman to serve as RBA governor, replacing Philip Lowe
# ListItem: Following claims a public servant urinated on colleagues, pesticides authority CEO and board chair resign
# ListItem: How Jesse's dress is overturning the army's gender diversity policy
# ListItem: Which age group of men are the loneliest? This survey had surprising results
# ListItem: analysisShould you stop drinking diet soft drinks after the new cancer advice?
# ListItem: Ukraine receives cluster munitions, pledges limited use as Russia threatens to use similar banned weaponry
# ListItem: 'It's very disturbing to me': Why Hollywood CEOs are outraged actors and writers have walked off the job
# ListItem: Actors in Hollywood are striking. Will your favourite TV show be impacted?
# ListItem: Australia mourned the death of one platypus — how can we save the entire species?
# ListItem: Huge dropout rate due to strict rule changes force Targa to cancel Tasmania, Queensland events
# ListItem: Officials trying to capture 'very bold' sea otter that's been wrestling surfboards off surfers
# ListItem: 20 years ago scientists discovered by chance that ketamine could help depression. More questions are getting answered
# ListItem: analysisA huge hurdle is coming for Dutton — but a bigger challenge is right behind
# ListItem: 'I haven't looked back': Meet the young women ditching hair dye and going grey
# Title: Popular Now
# UncategorizedText: 1.
# Title: How Jesse's dress is overturning the army's gender diversity policy
# UncategorizedText: 2.
# UncategorizedText: Is Michele Bullock the right choice as RBA governor? The experts are divided
# UncategorizedText: 3.
# UncategorizedText: Following claims a public servant urinated on colleagues, pesticides authority CEO and board chair resign
# UncategorizedText: 4.
# Title: analysis
# Title: analysis:Should you stop drinking diet soft drinks after the new cancer advice?
# UncategorizedText: 5.
# UncategorizedText: Which age group of men are the loneliest? This survey had surprising results
# UncategorizedText: 6.
# UncategorizedText: Officials trying to capture 'very bold' sea otter that's been wrestling surfboards off surfers
# Title: Top Stories
# NarrativeText: Is Michele Bullock the right choice as RBA governor? The experts are divided
# NarrativeText: Michele Bullock becomes first woman to serve as RBA governor, replacing Philip Lowe
# NarrativeText: Following claims a public servant urinated on colleagues, pesticides authority CEO and board chair resign
# NarrativeText: How Jesse's dress is overturning the army's gender diversity policy
# NarrativeText: Which age group of men are the loneliest? This survey had surprising results
# NarrativeText: analysisShould you stop drinking diet soft drinks after the new cancer advice?
# NarrativeText: Ukraine receives cluster munitions, pledges limited use as Russia threatens to use similar banned weaponry
# NarrativeText: 'It's very disturbing to me': Why Hollywood CEOs are outraged actors and writers have walked off the job
# NarrativeText: Actors in Hollywood are striking. Will your favourite TV show be impacted?
# Title: Just In
# ListItem: Actors in Hollywood are striking. Will your favourite TV show be impacted?13m ago13 minutes agoFri 14 Jul 2023 at 4:59am
# ListItem: All the latest COVID-19 case numbers from around Australia — plus the news you may have missed36m ago36 minutes agoFri 14 Jul 2023 at 4:36am
# ListItem: Council considers closing nursing home where great-grandmother was allegedly tasered, move 'not linked' to incident42m ago42 minutes agoFri 14 Jul 2023 at 4:30am
# ListItem: Teen accused of Easter Monday assault facing murder charge after 63-year-old's death42m ago42 minutes agoFri 14 Jul 2023 at 4:30am
# ListItem: Man who shot cousin over gold watch 'did not know his conduct was wrong', judge rules47m ago47 minutes agoFri 14 Jul 2023 at 4:24am
# ListItem: Is Michele Bullock the right choice as RBA governor? The experts are divided59m ago59 minutes agoFri 14 Jul 2023 at 4:12am
# Title: More Just In
# NarrativeText: Back to top

# %%
# Out:
# 31

# %%
# Identify article name and change its category
data_objects[0]['category'] = 'ArticleName'

# Identify authors and change category
# Iterate over the data_objects list
for item in data_objects:
    # Check if the category of the current item is 'Title' and the text starts with 'By '
    if item['category'] == 'Title' and item['text'].startswith('By '):
        # If it is, change the category to 'AuthorList' and remove 'By ' from the text
        item['category'] = 'AuthorList'
        item['text'] = item['text'][3:]  # Remove 'By ' from the start of the text
        # If there are exactly two authors (i.e., there is no comma and there is ' and' in the text)
        if ',' not in item['text'] and ' and' in item['text']:
            # Replace ' and' with ', '
            item['text'] = item['text'].replace(' and', ',')
        else:
            # If ' and' is in the text, remove it
            item['text'] = item['text'].replace(' and', '').strip()
        break


# Find the key points and assign to category 'KeyPoint'
# Define the start of the pattern
start_pattern = {"category": "Title", "text": "Key points:"}

# Iterate over the data_objects list
i = 0
while i < len(data_objects):
    # Check if the current element's 'category' and 'text' match those in the start pattern
    if data_objects[i].get('category') == start_pattern['category'] and data_objects[i].get('text') == start_pattern['text']:
        # If the start of the pattern is matched, remove this element
        del data_objects[i]
        # Then change the category of the following 'ListItem' elements to 'KeyPoint'
        while i < len(data_objects) and data_objects[i]["category"] == "ListItem":
            data_objects[i]["category"] = "KeyPoint"
            i += 1
    else:
        i += 1


# Remove the 'Read more' section
# Define the start of the sequence
start_sequence = {"category": "Title", "text": "Read more about the Indigenous Voice to Parliament:"}

# Iterate over the data_objects list
i = 0
while i < len(data_objects):
    # Check if the current element's 'category' and 'text' match those in the start sequence
    if data_objects[i].get('category') == start_sequence['category'] and data_objects[i].get('text') == start_sequence['text']:
        # If the start of the sequence is matched, remove this element
        del data_objects[i]
        # Then remove the following 'ListItem' elements
        while i < len(data_objects) and data_objects[i]["category"] == "ListItem":
            del data_objects[i]
    else:
        i += 1

# Remove elements matching the pattern "Title: Loading..."
# Define the pattern to remove
remove_pattern = {"category": "Title", "text": "Loading..."}

# Filter out the elements that match the remove pattern
data_objects = [d for d in data_objects if not (d.get('category') == remove_pattern['category'] and d.get('text') == remove_pattern['text'])]



# Cut off after "NarrativeText: If you're ..."
# Define the pattern to stop at
stop_pattern = {"category": "NarrativeText", "text": "If you're unable to load the form, you can access it here."}

# Find the index of the element with the stop pattern
stop_index = next((i for i, d in enumerate(data_objects) if d.get('category') == stop_pattern['category'] and d.get('text') == stop_pattern['text']), None)

# If the stop pattern was found, slice the list up to that index
if stop_index is not None:
    data_objects = data_objects[:stop_index]

# Cut off after "Title: Share"
# Define the pattern to stop at
stop_pattern = {"category": "Title", "text": "Share"}

# Find the index of the element with the stop pattern
stop_index = next((i for i, d in enumerate(data_objects) if d.get('category') == stop_pattern['category'] and d.get('text') == stop_pattern['text']), None)

# If the stop pattern was found, slice the list up to that index
if stop_index is not None:
    data_objects = data_objects[:stop_index]



# Identify publishing outlet
# Iterate over the data_objects list
for item in data_objects:
    # Check if the category of the current item is 'Title' and the text starts with 'ABC '
    if item['category'] == 'Title' and item['text'].startswith('ABC '):
        # If it is, change the category to 'PublishingOutlet' and keep the text as it is
        item['category'] = 'PublishingOutlet'
        break


# Remove fluff at start of article
# Remove rows matching the pattern "ABC " at the beginning and ")" at the end
data_objects = [
    item for item in data_objects if not (
        item['text'] == 'updated' or
        item['text'] == 'Copy link' or
        item['text'] == 'Posted' or
        item['text'] == 'Help keep family & friends informed by sharing this article' or
        item['text'] == 'Link copied' or
        item['text'].startswith('abc.net.au') or 
        (item['text'].startswith('ABC ') and item['text'].endswith(')') and '(' not in item['text']) or
        (item['text'].startswith('Supplied: ') and item['text'].endswith(')') and '(' not in item['text'])
    )
]
for i, d in enumerate(data_objects):
    print("{0}: {1}".format(d['category'], d['text']))
# Out:
# ArticleName: Thousands take to streets for 2023 NAIDOC parade in Darwin CBD
# AuthorList: Kyle Dowling
# NarrativeText: Thousands of people have taken to the streets of Darwin CBD for a NAIDOC parade that saw leaders rally for a Yes vote in the upcoming referendum on an Indigenous Voice to Parliament.
# KeyPoint: Larrakia Nation renewed calls for a treaty with the Northern Territory government
# KeyPoint: The peak body for Aboriginal organisations says a Voice to Parliament is "a way forward"
# KeyPoint: This year's NAIDOC theme is For Our Elders
# NarrativeText: The city saw one of the largest turnouts in recent years as people marched through the streets calling for respect for elders, and highlighting the desire for treaty.
# NarrativeText: Jerome Cubillo, the chair of Larrakia Nation — the peak body for traditional owners in the area — acknowledged previous work towards treaty and called for governments to take steps forward once again.
# NarrativeText: "We want to continue to hold our politicians accountable to say, 'We had momentum for a treaty in the Northern Territory. Where has that momentum gone? Where has that bravery gone?'"
# NarrativeText: "So we stand here, again, calling on the Northern Territory government to work with us [and] find a way … to get a treaty process back up," Mr Cubillo said.
# NarrativeText: "[It's the] only way to make our mob stronger, to give our mob a better future."
# NarrativeText: The event also focused on the upcoming Voice to Parliament referendum.
# NarrativeText: John Paterson, a spokesperson for the Aboriginal Peak Organisations of the Northern Territory (APONT), said it was a way forward for First Nations Australians.
# NarrativeText: "With a Voice, we will be able to speak up and be heard for our families, our communities, our country and for elders," he said.
# NarrativeText: "Bring Aboriginal leadership and Aboriginal voices into policymaking is the only way to make our mob stronger, to give our mob a better future."
# UncategorizedText: Northern Territory Aboriginal Affairs Minister Selena Uibo stressed the significance of the referendum.
# NarrativeText: "Eight per cent of Australia's population will decide for the 2 per cent of us," she said.
# NarrativeText: "They'll determine the fate of Aboriginal and Torres Strait Islander futures.
# NarrativeText: "Our fate will be decided by one of two words: no or yes.
# NarrativeText: "We cannot wait another 56 years to have a voice on our own affairs."
# Title: A time for solidarity, elders, and future generations
# NarrativeText: This year's NAIDOC theme is "For Our Elders" and is about recognising the importance of past generations and their journey and fight for the rights of First Nations people.
# NarrativeText: Michael McMahon, who has lived in Darwin for decades, said for him, this year's event was incredibly important.
# NarrativeText: "[Elders] helped us to shape our futures, and then for future generations to come," he said.
# NarrativeText: "I'm really looking forward to being a part of that and to seeing the younger, younger generation come through as well."
# NarrativeText: NAIDOC Week brings together not only Aboriginal and Torres Strait Islander groups but also the wider Australian community.
# NarrativeText: For those who attended the march, this unity is essential.
# NarrativeText: "It's really important for all of our mobs, especially everyone from different mobs — you've got people from different states, different towns, different communities coming together — and we're all celebrating NAIDOC Week," Darwin resident Ayesha Kay said.
# NarrativeText: For Darren Griffon, this coming together is what NAIDOC is all about.
# NarrativeText: "The main reason is to be united as one, to get together, show support for everybody," he said.
# NarrativeText: "Different tribes, you know, we've got a lot of diversity and tribes and that, so to come together, it's really good."

# %%
len(data_objects)
# Out:
# 137

# %%
abc_class = {
    'class': 'ABCNewsArticle',
    'description': 'Class for ABC News articles',
    'properties': [
        {'name': 'text', 'dataType': ['text']},
        {'name': 'category', 'dataType': ['text']},
        {'name': 'article_name', 'dataType': ['text']},
        {'name': 'author_list', 'dataType': ['text']}, #
        {'name': 'publisher', 'dataType': ['text']}, #
        {'name': 'date', 'dataType': ['text']},
        {'name': 'url', 'dataType': ['text']},
        {'name': 'tags', 'dataType': ['text']},
        {'name': 'upload_note', 'dataType': ['text']},
    ],
    'vectorizer': 'text2vec-openai', 
    "moduleConfig": {
        "text2vec-openai": {
            "vectorizeClassName": False
        }
    },
}


client = weaviate.Client(
    url=weaviate_url,
    auth_client_secret=weaviate.AuthApiKey(api_key=weaviate_api_key),
    additional_headers= {
        "X-OpenAI-Api-Key": openai_api_key,
    }
)

# %%
unstructured_class = {
    'class': 'UnstructuredDocument',
    'description': 'General class for all documents (todo: add more specific classes)',
    'properties': [
        {'name': 'text', 'dataType': ['text']},
        {'name': 'category', 'dataType': ['text']},
        {'name': 'filename', 'dataType': ['text']},
        {'name': 'file_directory', 'dataType': ['text']},
        {'name': 'date', 'dataType': ['text']},
        {'name': 'filetype', 'dataType': ['text']},
        {'name': 'attached_to_filename', 'dataType': ['text']},
        {'name': 'page_number', 'dataType': ['int']},
        {'name': 'page_name', 'dataType': ['text']},
        {'name': 'url', 'dataType': ['text']},
        {'name': 'sent_from', 'dataType': ['text']},
        {'name': 'sent_to', 'dataType': ['text']},
        {'name': 'subject', 'dataType': ['text']},
        {'name': 'header_footer_type', 'dataType': ['text']},
        {'name': 'text_as_html', 'dataType': ['text']},
        {'name': 'regex_metadata', 'dataType': ['text']},
        {'name': 'tags', 'dataType': ['text']},
        {'name': 'upload_note', 'dataType': ['text']},
    ],
    'vectorizer': 'text2vec-openai', 
    "moduleConfig": {
        "text2vec-openai": {
            "vectorizeClassName": False
        }
    },

}

# %% [markdown]
# ## Modifying the schema
# Below code blocks are used to update the schema in Weaviate. Don't need to run this every time.

# %% [markdown]
# ### Create schema with the defined classes

# %%
schema = {"classes": [unstructured_class, abc_class]}
# add the ABCNewsArticle class to the schema
#schema["classes"].append(abc_class)
client.schema.create(schema)

# %% [markdown]
# ### Print defined schemas

# %%
schema = client.schema.get()
print(schema)
# Out:
# {'classes': [{'class': 'UnstructuredDocument', 'description': 'General class for all documents (todo: add more specific classes)', 'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2}, 'cleanupIntervalSeconds': 60, 'stopwords': {'additions': None, 'preset': 'en', 'removals': None}}, 'moduleConfig': {'text2vec-openai': {'model': 'ada', 'modelVersion': '002', 'type': 'text', 'vectorizeClassName': False}}, 'multiTenancyConfig': {'enabled': False}, 'properties': [{'dataType': ['text'], 'indexFilterable': True, 'indexSearchable': True, 'moduleConfig': {'text2vec-openai': {'skip': False, 'vectorizePropertyName': False}}, 'name': 'text', 'tokenization': 'word'}, {'dataType': ['text'], 'indexFilterable': True, 'indexSearchable': True, 'moduleConfig': {'text2vec-openai': {'skip': False, 'vectorizePropertyName': False}}, 'name': 'category', 'tokenization': 'word'}, {'dataType': ['text'], 'indexFilterable': True, 'indexSearchable': True, 'moduleConfig': {'text2vec-openai': {'skip': False, 'vectorizePropertyName': False}}, 'name': 'filename', 'tokenization': 'word'}, {'dataType': ['text'], 'indexFilterable': True, 'indexSearchable': True, 'moduleConfig': {'text2vec-openai': {'skip': False, 'vectorizePropertyName': False}}, 'name': 'file_directory', 'tokenization': 'word'}, {'dataType': ['text'], 'indexFilterable': True, 'indexSearchable': True, 'moduleConfig': {'text2vec-openai': {'skip': False, 'vectorizePropertyName': False}}, 'name': 'date', 'tokenization': 'word'}, {'dataType': ['text'], 'indexFilterable': True, 'indexSearchable': True, 'moduleConfig': {'text2vec-openai': {'skip': False, 'vectorizePropertyName': False}}, 'name': 'filetype', 'tokenization': 'word'}, {'dataType': ['text'], 'indexFilterable': True, 'indexSearchable': True, 'moduleConfig': {'text2vec-openai': {'skip': False, 'vectorizePropertyName': False}}, 'name': 'attached_to_filename', 'tokenization': 'word'}, {'dataType': ['int'], 'indexFilterable': True, 'indexSearchable': False, 'moduleConfig': {'text2vec-openai': {'skip': False, 'vectorizePropertyName': False}}, 'name': 'page_number'}, {'dataType': ['text'], 'indexFilterable': True, 'indexSearchable': True, 'moduleConfig': {'text2vec-openai': {'skip': False, 'vectorizePropertyName': False}}, 'name': 'page_name', 'tokenization': 'word'}, {'dataType': ['text'], 'indexFilterable': True, 'indexSearchable': True, 'moduleConfig': {'text2vec-openai': {'skip': False, 'vectorizePropertyName': False}}, 'name': 'url', 'tokenization': 'word'}, {'dataType': ['text'], 'indexFilterable': True, 'indexSearchable': True, 'moduleConfig': {'text2vec-openai': {'skip': False, 'vectorizePropertyName': False}}, 'name': 'sent_from', 'tokenization': 'word'}, {'dataType': ['text'], 'indexFilterable': True, 'indexSearchable': True, 'moduleConfig': {'text2vec-openai': {'skip': False, 'vectorizePropertyName': False}}, 'name': 'sent_to', 'tokenization': 'word'}, {'dataType': ['text'], 'indexFilterable': True, 'indexSearchable': True, 'moduleConfig': {'text2vec-openai': {'skip': False, 'vectorizePropertyName': False}}, 'name': 'subject', 'tokenization': 'word'}, {'dataType': ['text'], 'indexFilterable': True, 'indexSearchable': True, 'moduleConfig': {'text2vec-openai': {'skip': False, 'vectorizePropertyName': False}}, 'name': 'header_footer_type', 'tokenization': 'word'}, {'dataType': ['text'], 'indexFilterable': True, 'indexSearchable': True, 'moduleConfig': {'text2vec-openai': {'skip': False, 'vectorizePropertyName': False}}, 'name': 'text_as_html', 'tokenization': 'word'}, {'dataType': ['text'], 'indexFilterable': True, 'indexSearchable': True, 'moduleConfig': {'text2vec-openai': {'skip': False, 'vectorizePropertyName': False}}, 'name': 'regex_metadata', 'tokenization': 'word'}, {'dataType': ['text'], 'indexFilterable': True, 'indexSearchable': True, 'moduleConfig': {'text2vec-openai': {'skip': False, 'vectorizePropertyName': False}}, 'name': 'tags', 'tokenization': 'word'}, {'dataType': ['text'], 'indexFilterable': True, 'indexSearchable': ...

# %% [markdown]
# ### Delete all classes in schema

# %%
schema = client.schema.get()

for class_info in schema['classes']:
    class_name = class_info['class']
    client.schema.delete_class(class_name)

# %% [markdown]
# ### Show properties of the first class in the schema

# %%
schema = client.schema.get()
schema['classes'][1]
# Out:
# {'class': 'ABCNewsArticle',
#  'description': 'Class for ABC News articles',
#  'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#   'cleanupIntervalSeconds': 60,
#   'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#  'moduleConfig': {'text2vec-openai': {'model': 'ada',
#    'modelVersion': '002',
#    'type': 'text',
#    'vectorizeClassName': False}},
#  'multiTenancyConfig': {'enabled': False},
#  'properties': [{'dataType': ['text'],
#    'indexFilterable': True,
#    'indexSearchable': True,
#    'moduleConfig': {'text2vec-openai': {'skip': False,
#      'vectorizePropertyName': False}},
#    'name': 'text',
#    'tokenization': 'word'},
#   {'dataType': ['text'],
#    'indexFilterable': True,
#    'indexSearchable': True,
#    'moduleConfig': {'text2vec-openai': {'skip': False,
#      'vectorizePropertyName': False}},
#    'name': 'category',
#    'tokenization': 'word'},
#   {'dataType': ['text'],
#    'indexFilterable': True,
#    'indexSearchable': True,
#    'moduleConfig': {'text2vec-openai': {'skip': False,
#      'vectorizePropertyName': False}},
#    'name': 'article_name',
#    'tokenization': 'word'},
#   {'dataType': ['text'],
#    'indexFilterable': True,
#    'indexSearchable': True,
#    'moduleConfig': {'text2vec-openai': {'skip': False,
#      'vectorizePropertyName': False}},
#    'name': 'date',
#    'tokenization': 'word'},
#   {'dataType': ['text'],
#    'indexFilterable': True,
#    'indexSearchable': True,
#    'moduleConfig': {'text2vec-openai': {'skip': False,
#      'vectorizePropertyName': False}},
#    'name': 'url',
#    'tokenization': 'word'},
#   {'dataType': ['text'],
#    'indexFilterable': True,
#    'indexSearchable': True,
#    'moduleConfig': {'text2vec-openai': {'skip': False,
#      'vectorizePropertyName': False}},
#    'name': 'tags',
#    'tokenization': 'word'},
#   {'dataType': ['text'],
#    'indexFilterable': True,
#    'indexSearchable': True,
#    'moduleConfig': {'text2vec-openai': {'skip': False,
#      'vectorizePropertyName': False}},
#    'name': 'upload_note',
#    'tokenization': 'word'}],
#  'replicationConfig': {'factor': 1},
#  'shardingConfig': {'virtualPerPhysical': 128,
#   'desiredCount': 1,
#   'actualCount': 1,
#   'desiredVirtualCount': 128,
#   'actualVirtualCount': 128,
#   'key': '_id',
#   'strategy': 'hash',
#   'function': 'murmur3'},
#  'vectorIndexConfig': {'skip': False,
#   'cleanupIntervalSeconds': 300,
#   'maxConnections': 64,
#   'efConstruction': 128,
#   'ef': -1,
#   'dynamicEfMin': 100,
#   'dynamicEfMax': 500,
#   'dynamicEfFactor': 8,
#   'vectorCacheMaxObjects': 1000000000000,
#   'flatSearchCutoff': 40000,
#   'distance': 'cosine',
#   'pq': {'enabled': False,
#    'bitCompression': False,
#    'segments': 0,
#    'centroids': 256,
#    'trainingLimit': 100000,
#    'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}}},
#  'vectorIndexType': 'hnsw',
#  'vectorizer': 'text2vec-openai'}

# %% [markdown]
# ## Ingest document data using Unstructured
# Unstructured allows essentially any file to be uploaded and text data extracted. Testing on documents in `../data/`.

# %%
doc_elements = partition("../data/Politics and the English Language - George Orwell.pdf")
data_objects = stage_for_weaviate(doc_elements)

for key in ['filename', 'file_directory', 'filetype', 'page_number', 'text', 'category']:
    print("{0}: {1}".format(key, data_objects[0][key]))
# Out:
# filename: Politics and the English Language - George Orwell.pdf
# file_directory: ../data
# filetype: application/pdf
# page_number: 1
# text: Politics and the English Language - George Orwell
# category: Title

# %%
data_objects[0].keys()
# Out:
# dict_keys(['filetype', 'page_number', 'text', 'category'])

# %% [markdown]
# Not sure how much of the above data actually needs to be stored. Store it all for now, but there's likely more interesting metadata to be added here. Examples might be a sentiment analysis score, GPT-generated summary, external links and internal links, etc.
#
# Upload to Weaviate with the uploaded data fitting the defined schema:

# %%
# show the first data object of UncategorizedTest 
data_objects[0]['text']
# Out:
# "Indigenous community's handling of COVID shows why Voice to Parliament needed, Fiona Stanley says"

# %%
upload_note = "Fiona Stanley praises the Aboriginal response to COVID-19, calling it the best in the world and a strong argument for an Indigenous Voice to Parliament. She highlighted that contrary to expectations, there were significantly fewer COVID-19 cases among Indigenous Australians compared to their non-Indigenous counterparts at the start of the pandemic. Stanley attributes this success to the high level of input and self-determination in health responses during the pandemic, stating that the Aboriginal response is the best example of why a Voice is going to make such a difference."
tags = "voice to parliament, covid-19"


with client.batch(batch_size=10) as batch:
    for i, d in enumerate(data_objects):  
        properties = {
            'category': d['category'],
            'text': d['text'],
            'article_name' : data_objects[0]['text'],
            'url': article_url,
            'filetype': d['filetype'],
            'date': date.today().strftime("%Y-%m-%d"),
            'upload_note': upload_note, # testing
            'tags': tags # testing
        }
        batch.add_data_object(
            properties,
            'ABCNewsArticle',
            uuid=generate_uuid5(properties),
        )

# %% [markdown]
# ## Querying Weaviate
# Once the data is in Weaviate, a NearText search (to research) can be performed to find concepts similar to user input:

# %%
nearText = {"concepts": ["renters", "cost of living"]}

client = weaviate.Client(
    url=weaviate_url,
    auth_client_secret=weaviate.AuthApiKey(api_key=weaviate_api_key),
    additional_headers= {
        "X-OpenAI-Api-Key": openai_api_key,
    }
)


response = (
    client.query  # start a new query
    .get("ABCNewsArticle", ["text", "article_name", "upload_note", "tags"])  # get objects of the "UnstructuredDocument" class and retrieve their "text" property
    .with_near_text(nearText)  # find objects that are semantically similar to the text in "nearText"
    .with_limit(6)  # limit the results to the top 2 most similar objects
    #.with_where({
    #    "path": ["tags"],
    #    "operator": "Equal",
    #    "valueString": "updatedtest"
    #})
    .do()  # execute the query
)

# %%
client = weaviate.Client(
    url=weaviate_url,
    auth_client_secret=weaviate.AuthApiKey(api_key=weaviate_api_key),
    additional_headers= {
        "X-OpenAI-Api-Key": openai_api_key,
    }
)

response = (
    client.query  # start a new query
    .get("ABCNewsArticle", ["text", "article_name", "category"])  # limit the results to the top 2 most similar objects
    .with_where({
        "path": ["tags"],
        "operator": "Equal",
        "valueString": "test"
    })
    .do()  # execute the query
)

# %%
# extract text from response
print("title: " + response['data']['Get']['ABCNewsArticle'][0]['text'])
for i, r in enumerate(response['data']['Get']['ABCNewsArticle']):
    print("\ncategory: {0}\ncontent: {1}"
    .format(r['category'], r['text']))
# Out:
# title: Former Australian of the Year Fiona Stanley believes Aboriginal people had the best response to COVID-19 "in the world", and says it proves an Indigenous Voice to Parliament will improve health outcomes for First Nations people.
#
# category: NarrativeText
# content: Former Australian of the Year Fiona Stanley believes Aboriginal people had the best response to COVID-19 "in the world", and says it proves an Indigenous Voice to Parliament will improve health outcomes for First Nations people.
#
# category: UncategorizedText
# content: Indigenous community's handling of COVID shows why Voice to Parliament needed, Fiona Stanley says
#
# category: NarrativeText
# content: Help keep family & friends informed by sharing this article
#
# category: Title
# content: Copy link
#
# category: NarrativeText
# content: Link copied
#
# category: Title
# content: By Daryna Zadvirna
#
# category: Title
# content: abc.net.au/news/covid-response-shows-indigenous-voice-needed-fiona-stanley-says/102582244
#
# category: Title
# content: ABC News: Daryna Zadvirna)
#
# category: NarrativeText
# content: Speaking at a panel discussion in support of the Voice on Monday evening, the epidemiologist noted for her public health work, said there was evidence showing the Voice referendum would make a significant difference to Indigenous people's lives.
#
# category: NarrativeText
# content: "We would have anticipated because of the high risks of Aboriginal people — chronic disease, overcrowded conditions, and most Aboriginal people actually live in cities, only 18 per cent live in remote communities – they were of high risk [of contracting the virus]," she said.
#
# category: ListItem
# content: She says their pandemic response shows a Voice will make a difference
#
# category: Title
# content: Key points:
#
# category: ListItem
# content: Fiona Stanley says Indigenous people benefited from having a say on COVID
#
# category: ListItem
# content: But debate continues over the Voice, with critics saying it remains confusing
#
# category: NarrativeText
# content: "They had a Voice in the National Aboriginal Community Controlled Health Organisation. They had a Voice at all state and territory organisations right down to communities."
#
# category: NarrativeText
# content: "Well, within the first 18 to 20 months of the pandemic, Aboriginal people had six times fewer cases than non-Indigenous people did. How did they do it? They had a voice.
#
# category: NarrativeText
# content: Professor Stanley said contrary to expectation, there were significantly fewer COVID-19 cases among Indigenous Australians compared to their non-Indigenous counterparts at the start of the pandemic.
#
# category: NarrativeText
# content: "We already know the Yes campaign have the hardest job ... to convince Australians that this is something that is worthwhile for the future.
#
# category: NarrativeText
# content: Professor Stanley was a panellist at the pro-Voice event, along with former High Court chief justice Robert French and author Thomas Mayo.
#
# category: Title
# content: Debate reminiscent of Mabo: Dorinda Cox
#
# category: NarrativeText
# content: Professor Stanley told the event in Perth that the relatively small number of COVID-19 cases among Indigenous Australians was the result of the high level of input and self-determination in health responses during the pandemic.
#
# category: NarrativeText
# content: She echoed concerns raised by former WA Aboriginal affairs minister Ben Wyatt that the state's controversial new Aboriginal heritage laws were being used as a weapon against the referendum.
#
# category: NarrativeText
# content: "The Aboriginal response to the pandemic was the best in the world," she said.
#
# category: NarrativeText
# content: "And it is the best example of why a Voice is going to make such a difference."
#
# category: NarrativeText
# content: Speaking earlier on Monday at a media event in Perth as part of the Yes campaign, WA senator Dorinda Cox said attempts to use new heritage laws as a tool to oppose the Voice were reminiscent of Australians being warned they would "lose their backyards" over the Mabo decision.
#
# category: NarrativeText
# content: "I think what needs to be stopped is the scaremongering and putting those two things together [is] enabling a conversation that is destructive," Senator Cox said.
#
# category: NarrativeText
# content: The Voice would be an independent body advising parliament and government about matters that affect the lives of Aboriginal and Torres Strait Islander Australians.
#
# category: NarrativeText
# content: Federal MP for Perth Patrick Gorman said constitutional recognition was more significant for West Australians than the GST.
#
# category: Title
# content: ABC News)
#
# category: NarrativeText
# content: "This is bigger than the GST because it is about something for the next generation, it's about bringing people together, it's about closing that gap that for too long we have not been able to close in doing things the same way year in, year out."
#
# category: NarrativeText
# content: What is the Voice to Parliament?We break down everything to do with the Indigenous Voice to Parliament referendum.Read more
#
# category: NarrativeText
# content: Australians will vote later this year on whether or not to enshrine an Indigenous Voice to Parliament in the constitution.
#
# category: NarrativeText
# content: Loading YouTube content
#
# category: NarrativeText
# content: "I think putting those two things together is what we saw in the days of the Mabo decision, that people would lose their backyards. And we don't want to go back to that, that's part of history.
#
# category: Title
# content: Bigger for WA than GST, declares Patrick Gorman
#
# category: NarrativeText
# content: "What we want to do is look forward to what we see as a reconciled Australia."
#
# category: NarrativeText
# content: In a sign of how crucial WA's vote is in the referendum, Indigenous Affairs Minister Linda Burney will on Monday begin a tour of regional WA to drum up support for the change.
#
# category: NarrativeText
# content: Indigenous activist Megan Krakouer is firmly in the No camp, and believes the Voice does not go far enough to achieve social reform.
#
# category: NarrativeText
# content: Ms Krakouer labelled comments on the heritage laws as a distraction that muddied the waters around the Voice proposal.
#
# category: Title
# content: ABC News: Briana Shepherd)
#
# category: NarrativeText
# content: It would only provide advice and would have no authority to overrule parliament.
#
# category: NarrativeText
# content: "I want to see something that has teeth in it, that can actually compel the social reforms that are much needed," she said.
#
# category: NarrativeText
# content: Some common suggestions in opposition to the Voice were that it would be divisive, that the proposal lacks clarity, and it would not have any real impact.
#
# category: Title
# content: Voice has no 'teeth', No campaigner says
#
# category: NarrativeText
# content: "There's enough confusion as to what the Voice means at this point and what it looks like," she said.
#
# category: NarrativeText
# content: "I have people saying, 'I don't know what the Voice is, is that John Farnham The Voice, is that the TV show The Voice?'"
#
# category: NarrativeText
# content: updated
#
# category: Title
# content: Loading...
#
# category: NarrativeText
# content: If you're unable to load the form, you can access it here.
#
# category: ListItem
# content: 'Systemic failure': WA youth detainees 'unlawfully confined' during lockdowns, court finds
#
# category: UncategorizedText
# content: Select "Western Australia Top Stories" from either the ABC News homepage or the settings menu in the app.
#
# category: Title
# content: Want more local WA news?
#
# category: ListItem
# content: Clancy the blue heeler survives a week in the bush after car rollover in remote WA
#
# category: ListItem
# content: Perth punching above its weight in competitive world of cycling, and proof is found at Tour de France
#
# category: Title
# content: Posted
#
# category: NarrativeText
# content: Here's some of the latest local reads from WA 📰
#
# category: Title
# content: More on:
#
# category: ListItem
# content:
#
# category: ListItem
# content: Facebook
#
# category: ListItem
# content: These advocates are voting differently on the Voice — they want you to know why
#
# category: ListItem
# content: Voice to Parliament 'damaging in the long term', former PM Tony Abbott says
#
# category: Title
# content: Related Stories
#
# category: ListItem
# content: Copy link
#
# category: ListItem
# content: Twitter
#
# category: Title
# content: Share
#
# category: ListItem
# content: WA recorded more 'no' votes than anywhere else in 1967 referendum, could 'myths' on the Voice see it happen again?
#
# category: ListItem
# content: 'She is not the victim here': Woman to be released from prison after pleading guilty to manslaughter of partner in violent fight
#
# category: ListItem
# content: Perth
#
# category: ListItem
# content: Aboriginal
#
# category: ListItem
# content: Referendums
#
# category: ListItem
# content: Work-from-home deal 'groundbreaking', but business groups warn of CBD 'death knell'
#
# category: ListItem
# content: Indigenous (Aboriginal and Torres Strait Islander)
#
# category: ListItem
# content: Indigenous Policy
#
# category: ListItem
# content: Government and Politics
#
# category: ListItem
# content: Young renters under most strain, but full mortgage pain yet to be felt, warns CBA boss
#
# category: ListItem
# content: Elon Musk, who has warned of AI's potential for 'civilisational destruction', launches own AI startup
#
# category: ListItem
# content: NASA's 'chaotic' new image reveals detail undetectable to the human eye
#
# category: ListItem
# content: Actor Vince Colosimo has tens of thousands in traffic fines wiped by court
#
# category: ListItem
# content: Zayn Malik opens up about One Direction departure in first interview in six years
#
# category: ListItem
# content: Russian general dismissed after accusing top officers of betraying soldiers
#
# category: ListItem
# content: AFL live: Swans seeking a boost against Bulldogs at SCG
#
# category: ListItem
# content: Ben Roberts-Smith judge accused of 'cherry-picking' evidence as war veteran's lawyers launch appeal
#
# category: ListItem
# content: After she was covered in hot volcanic ash, travel blogger Annie endured a horrifying journey to get help
#
# category: ListItem
# content: Rapper The Kid LAROI sponsors outback footy club's Indigenous guernsey
#
# category: ListItem
# content: Future Matildas to take football to 'next level' ahead of Women's World Cup
#
# category: UncategorizedText
# content: 4.
#
# category: ListItem
# content: Mum-of-10 forced to cut back on school lunches as food prices 'out of control'
#
# category: Title
# content: Popular Now
#
# category: UncategorizedText
# content: Actor Vince Colosimo has tens of thousands in traffic fines wiped by court
#
# category: Title
# content: Work-from-home deal 'groundbreaking', but business groups warn of CBD 'death knell'
#
# category: UncategorizedText
# content: 2.
#
# category: UncategorizedText
# content: 3.
#
# category: Title
# content: Russian general dismissed after accusing top officers of betraying soldiers
#
# category: UncategorizedText
# content: 1.
#
# category: ListItem
# content: Battery eggs on the way out — eventually — as ministers agree they have to go
#
# category: NarrativeText
# content: Russian general dismissed after accusing top officers of betraying soldiers
#
# category: UncategorizedText
# content: 5.
#
# category: NarrativeText
# content: Work-from-home deal 'groundbreaking', but business groups warn of CBD 'death knell'
#
# category: UncategorizedText
# content: After she was covered in hot volcanic ash, travel blogger Annie endured a horrifying journey to get help
#
# category: UncategorizedText
# content: 'She is not the victim here': Woman to be released from prison after pleading guilty to manslaughter of partner in violent fight
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
