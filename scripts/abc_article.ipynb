# %% [markdown]
# # Handling ABC Articles

# %%
from unstructured.partition.auto import partition
from unstructured.documents.elements import *
from unstructured.staging.weaviate import create_unstructured_weaviate_class, stage_for_weaviate

import weaviate
from weaviate.util import generate_uuid5

from dotenv import load_dotenv
import os
import json
from datetime import date
import tqdm
load_dotenv()
# Out:
# True

# %%
weaviate_url = os.getenv("WEAVIATE_URL")
weaviate_api_key = os.getenv("WEAVIATE_API_KEY")
openai_api_key=os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ## Weaviate schemas
# Schemas are patterns for data. The template that exists is a good base but this layer is ripe for customization.
#
# Allowing user input here can assist with searching later on. The recommendation engine can use tags to help put useful information in front of me. Auto-ingesting data could also use tags for reliable sources (e.g. #media)
#
# A blank text box (upload note - i like the name reverie) which would be useful for experimenting and curating a database.

# %% [markdown]
# What follows is the definition a generalized 'unstructured document' class for Weaviate. Once this is working, next step is to make one for a specific use-case, e.g. abc online articles.

# %%
article_url = "https://www.abc.net.au/news/2023-07-11/covid-response-shows-indigenous-voice-needed-fiona-stanley-says/102582244"
import requests
from unstructured.partition.auto import partition
from unstructured.staging.weaviate import stage_for_weaviate
from unstructured.partition.html import partition_html

# Fetch data from URL
html_content = requests.get(article_url).text


# Assuming html_content is the HTML content you got from the URL
elements = partition_html(text=html_content)
data_objects = stage_for_weaviate(elements)

# %%
data_objects
# Out:
# [{'filetype': 'text/html',
#   'page_number': 1,
#   'text': "Indigenous community's handling of COVID shows why Voice to Parliament needed, Fiona Stanley says",
#   'category': 'UncategorizedText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'By Daryna Zadvirna',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Posted',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'updated',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'ABC News: Daryna Zadvirna)',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Help keep family & friends informed by sharing this article',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'abc.net.au/news/covid-response-shows-indigenous-voice-needed-fiona-stanley-says/102582244',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Link copied',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Copy link',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Former Australian of the Year Fiona Stanley believes Aboriginal people had the best response to COVID-19 "in the world", and says it proves an Indigenous Voice to Parliament will improve health outcomes for First Nations people.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Key points:',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Fiona Stanley says Indigenous people benefited from having a say on COVID',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'She says their pandemic response shows a Voice will make a difference',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'But debate continues over the Voice, with critics saying it remains confusing',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "Speaking at a panel discussion in support of the Voice\xa0on Monday evening, the\xa0epidemiologist\xa0noted for her public health work,\xa0said there was evidence showing the Voice referendum would make a significant difference to Indigenous people's lives.",
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Professor Stanley\xa0said contrary to expectation, there were significantly fewer COVID-19 cases among Indigenous Australians compared to their non-Indigenous counterparts at the start of the pandemic.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '"We would have anticipated because of the high risks of Aboriginal people — chronic disease, overcrowded conditions,\xa0and most Aboriginal people actually live in cities,\xa0only 18 per cent live in remote communities – they were of high risk [of contracting the virus]," she\xa0said.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '"Well, within the first 18 to 20 months of the pandemic, Aboriginal people had six times fewer cases than non-Indigenous people did. How did they do it? They had a voice.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '"They had a Voice in the National Aboriginal Community Controlled Health Organisation. They had a Voice at all state and territory organisations right down to communities."',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'ABC News: Daryna Zadvirna)',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Professor Stanley told the event in Perth that the relatively small number of COVID-19 cases among Indigenous Australians was the result of the high level of input and self-determination in health responses during the pandemic.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '"The Aboriginal response to the pandemic was the best in the world," she said.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '"And it is the best example of why a Voice is going to make such a difference."',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Professor Stanley was a panellist at the pro-Voice event, along with former High Court chief justice Robert French and author Thomas Mayo.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Debate reminiscent of Mabo: Dorinda Cox',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Speaking earlier on Monday at a media event in Perth as part of the Yes campaign, WA senator Dorinda Cox said attempts to use new heritage laws as a tool to oppose the Voice were reminiscent of Australians being warned they would "lose their backyards" over the Mabo decision.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "She echoed concerns raised by former WA Aboriginal affairs minister Ben Wyatt that the state's controversial new Aboriginal heritage laws were being used as a weapon against the referendum.",
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'ABC News)',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '"I think what needs to be stopped is the scaremongering and putting those two things together [is] enabling a conversation that is destructive," Senator Cox said.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '"We already know the Yes campaign have the hardest job ...\xa0to convince Australians that this is something that is worthwhile for the future.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '"I think putting those two things together is what we saw in the days of the Mabo decision, that people would lose their backyards. And we don\'t want to go back to that, that\'s part of history.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '"What we want to do is look forward to what we see as a reconciled Australia."',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Loading YouTube content',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Bigger for WA than GST, declares Patrick Gorman',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Federal MP for Perth Patrick Gorman said\xa0constitutional recognition was more significant for West Australians than the GST.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '"This is bigger than the GST because it is about something for the next generation, it\'s about bringing people together, it\'s about closing that gap that for too long we have not been able to close in doing things the same way year in, year out."',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'ABC News)',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Australians will vote later this year\xa0on whether or not to enshrine an Indigenous\xa0Voice to Parliament in the constitution.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'What is the Voice to Parliament?We break down everything to do with the Indigenous\xa0Voice to Parliament referendum.Read more',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'The Voice would be an independent body advising parliament and government about matters that affect the lives of Aboriginal and Torres Strait Islander Australians.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'It would only provide advice\xa0and would have no authority to overrule parliament.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Some common suggestions in opposition to the Voice were that\xa0it would be divisive, that the proposal lacks clarity, and it would not have any real impact.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "Voice has no 'teeth', No campaigner says",
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Indigenous activist Megan Krakouer is firmly in the No camp, and believes the Voice does not\xa0go\xa0far enough to achieve social reform.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'ABC News: Briana Shepherd)',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '"I want to see something that has teeth in it, that can actually compel the social reforms that are much needed," she said.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Ms Krakouer labelled comments on the heritage laws as a distraction that muddied\xa0the waters around the Voice proposal.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '"There\'s enough confusion\xa0as to what the Voice means at this point and what it looks like," she said.',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '"I have people saying, \'I don\'t know what the Voice is, is that John Farnham The Voice, is that the TV show The Voice?\'"',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "In a sign of how crucial WA's vote is in the referendum, Indigenous Affairs Minister Linda Burney will on Monday begin a tour of regional WA to drum up support for the change.",
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Loading...',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "If you're unable to load the form, you can access it here.",
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Want more local WA news?',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Select\xa0"Western Australia\xa0Top Stories"\xa0from either the ABC News homepage or the settings menu in the app.',
#   'category': 'UncategorizedText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "Here's some of the latest local reads from WA\xa0📰",
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "'Systemic failure': WA youth detainees 'unlawfully confined' during lockdowns, court finds",
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Clancy the blue heeler survives a week in the bush after car rollover in remote WA',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Perth punching above its weight in competitive world of cycling, and proof is found at Tour de France',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Posted',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'updated',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Share',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Copy link',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Facebook',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Twitter',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Related Stories',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "Voice to Parliament 'damaging in the long term', former PM Tony Abbott says",
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'These advocates are voting differently on the Voice — they want you to know why',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "WA recorded more 'no' votes than anywhere else in 1967 referendum, could 'myths' on the Voice see it happen again?",
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'More on:',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Aboriginal',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Government and Politics',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Indigenous (Aboriginal and Torres Strait Islander)',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Indigenous Policy',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Perth',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Referendums',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Top Stories',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Young renters under most strain, but full mortgage pain yet to be felt, warns CBA boss',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "Work-from-home deal 'groundbreaking', but business groups warn of CBD 'death knell'",
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "'She is not the victim here': Woman to be released from prison after pleading guilty to manslaughter of partner in violent fight",
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'After she was covered in hot volcanic ash, travel blogger Annie endured a horrifying journey to get help',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Russian general dismissed after accusing top officers of betraying soldiers',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Actor Vince Colosimo has tens of thousands in traffic fines wiped by court',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Zayn Malik opens up about One Direction departure in first interview in six years',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "NASA's 'chaotic' new image reveals detail undetectable to the human eye",
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "Future Matildas to take football to 'next level' ahead of Women's World Cup",
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "Ben Roberts-Smith judge accused of 'cherry-picking' evidence as war veteran's lawyers launch appeal",
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'End date endorsed for caged eggs but states, territories left to make final call',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "Rapper The Kid LAROI sponsors outback footy club's Indigenous guernsey",
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'AFL live: Swans seeking a boost against Bulldogs at SCG',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "Elon Musk, who has warned of AI's potential for 'civilisational destruction', launches own AI startup",
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'New Australian airline Bonza scraps five routes, reduces regional flights due to low demand',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Popular Now',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '1.',
#   'category': 'UncategorizedText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Actor Vince Colosimo has tens of thousands in traffic fines wiped by court',
#   'category': 'UncategorizedText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '2.',
#   'category': 'UncategorizedText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "Work-from-home deal 'groundbreaking', but business groups warn of CBD 'death knell'",
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '3.',
#   'category': 'UncategorizedText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Young renters under most strain, but full mortgage pain yet to be felt, warns CBA boss',
#   'category': 'UncategorizedText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '4.',
#   'category': 'UncategorizedText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "'She is not the victim here': Woman to be released from prison after pleading guilty to manslaughter of partner in violent fight",
#   'category': 'UncategorizedText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '5.',
#   'category': 'UncategorizedText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Russian general dismissed after accusing top officers of betraying soldiers',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': '6.',
#   'category': 'UncategorizedText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'New Australian airline Bonza scraps five routes, reduces regional flights due to low demand',
#   'category': 'UncategorizedText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Top Stories',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Young renters under most strain, but full mortgage pain yet to be felt, warns CBA boss',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "Work-from-home deal 'groundbreaking', but business groups warn of CBD 'death knell'",
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "'She is not the victim here': Woman to be released from prison after pleading guilty to manslaughter of partner in violent fight",
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'After she was covered in hot volcanic ash, travel blogger Annie endured a horrifying journey to get help',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Russian general dismissed after accusing top officers of betraying soldiers',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Actor Vince Colosimo has tens of thousands in traffic fines wiped by court',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Zayn Malik opens up about One Direction departure in first interview in six years',
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "NASA's 'chaotic' new image reveals detail undetectable to the human eye",
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "Future Matildas to take football to 'next level' ahead of Women's World Cup",
#   'category': 'NarrativeText'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Just In',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "Elon Musk, who has warned of AI's potential for 'civilisational destruction', launches own AI startup5m ago5 minutes agoThu 13 Jul 2023 at 8:58am",
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'AFL live: Swans seeking a boost against Bulldogs at SCG13m ago13 minutes agoThu 13 Jul 2023 at 8:50am',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "Water authority says spilling not the same as flooding as residents sweat on lake's flows38m ago38 minutes agoThu 13 Jul 2023 at 8:25am",
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': "Rapper The Kid LAROI sponsors outback footy club's Indigenous guernsey42m ago42 minutes agoThu 13 Jul 2023 at 8:21am",
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Russian general dismissed after accusing top officers of betraying soldiers55m ago55 minutes agoThu 13 Jul 2023 at 8:08am',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Soccer referee accused of indecently assaulting teenager pleads not guilty, returns home to New Zealand56m ago56 minutes agoThu 13 Jul 2023 at 8:07am',
#   'category': 'ListItem'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'More Just In',
#   'category': 'Title'},
#  {'filetype': 'text/html',
#   'page_number': 1,
#   'text': 'Back to top',
#   'category': 'NarrativeText'}]

# %%
abc_class = {
    'class': 'ABCNewsArticle',
    'description': 'Class for ABC News articles',
    'properties': [
        {'name': 'text', 'dataType': ['text']},
        {'name': 'category', 'dataType': ['text']},
        {'name': 'article_name', 'dataType': ['text']},
        {'name': 'date', 'dataType': ['text']},
        {'name': 'url', 'dataType': ['text']},
        {'name': 'tags', 'dataType': ['text']},
        {'name': 'upload_note', 'dataType': ['text']},
    ],
    'vectorizer': 'text2vec-openai', 
    "moduleConfig": {
        "text2vec-openai": {
            "vectorizeClassName": False
        }
    },

}


client = weaviate.Client(
    url=weaviate_url,
    auth_client_secret=weaviate.AuthApiKey(api_key=weaviate_api_key),
    additional_headers= {
        "X-OpenAI-Api-Key": openai_api_key,
    }
)

# %%
unstructured_class = {
    'class': 'UnstructuredDocument',
    'description': 'General class for all documents (todo: add more specific classes)',
    'properties': [
        {'name': 'text', 'dataType': ['text']},
        {'name': 'category', 'dataType': ['text']},
        {'name': 'filename', 'dataType': ['text']},
        {'name': 'file_directory', 'dataType': ['text']},
        {'name': 'date', 'dataType': ['text']},
        {'name': 'filetype', 'dataType': ['text']},
        {'name': 'attached_to_filename', 'dataType': ['text']},
        {'name': 'page_number', 'dataType': ['int']},
        {'name': 'page_name', 'dataType': ['text']},
        {'name': 'url', 'dataType': ['text']},
        {'name': 'sent_from', 'dataType': ['text']},
        {'name': 'sent_to', 'dataType': ['text']},
        {'name': 'subject', 'dataType': ['text']},
        {'name': 'header_footer_type', 'dataType': ['text']},
        {'name': 'text_as_html', 'dataType': ['text']},
        {'name': 'regex_metadata', 'dataType': ['text']},
        {'name': 'tags', 'dataType': ['text']},
        {'name': 'upload_note', 'dataType': ['text']},
    ],
    'vectorizer': 'text2vec-openai', 
    "moduleConfig": {
        "text2vec-openai": {
            "vectorizeClassName": False
        }
    },

}

# %% [markdown]
# ## Modifying the schema
# Below code blocks are used to update the schema in Weaviate. Don't need to run this every time.

# %% [markdown]
# ### Create schema with the defined classes

# %%
schema = {"classes": [unstructured_class, abc_class]}
# add the ABCNewsArticle class to the schema
#schema["classes"].append(abc_class)
client.schema.create(schema)

# %% [markdown]
# ### Print defined schemas

# %%
schema = {"classes": [abc_class]}

print(schema)
client.schema.create(schema)
# Out:
# {'classes': [{'class': 'ABCNewsArticle', 'description': 'Class for ABC News articles', 'properties': [{'name': 'text', 'dataType': ['text']}, {'name': 'category', 'dataType': ['text']}, {'name': 'article_name', 'dataType': ['text']}, {'name': 'date', 'dataType': ['text']}, {'name': 'url', 'dataType': ['text']}, {'name': 'tags', 'dataType': ['text']}, {'name': 'upload_note', 'dataType': ['text']}], 'vectorizer': 'text2vec-openai', 'moduleConfig': {'text2vec-openai': {'vectorizeClassName': False}}}]}

# %% [markdown]
# ### Delete all classes in schema

# %%
schema = client.schema.get()

for class_info in schema['classes']:
    class_name = class_info['class']
    client.schema.delete_class(class_name)

# %% [markdown]
# ### Show properties of the first class in the schema

# %%
schema = client.schema.get()
schema['classes'][1]
# Out:
# {'class': 'ABCNewsArticle',
#  'description': 'Class for ABC News articles',
#  'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#   'cleanupIntervalSeconds': 60,
#   'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#  'moduleConfig': {'text2vec-openai': {'model': 'ada',
#    'modelVersion': '002',
#    'type': 'text',
#    'vectorizeClassName': False}},
#  'multiTenancyConfig': {'enabled': False},
#  'properties': [{'dataType': ['text'],
#    'indexFilterable': True,
#    'indexSearchable': True,
#    'moduleConfig': {'text2vec-openai': {'skip': False,
#      'vectorizePropertyName': False}},
#    'name': 'text',
#    'tokenization': 'word'},
#   {'dataType': ['text'],
#    'indexFilterable': True,
#    'indexSearchable': True,
#    'moduleConfig': {'text2vec-openai': {'skip': False,
#      'vectorizePropertyName': False}},
#    'name': 'category',
#    'tokenization': 'word'},
#   {'dataType': ['text'],
#    'indexFilterable': True,
#    'indexSearchable': True,
#    'moduleConfig': {'text2vec-openai': {'skip': False,
#      'vectorizePropertyName': False}},
#    'name': 'article_name',
#    'tokenization': 'word'},
#   {'dataType': ['text'],
#    'indexFilterable': True,
#    'indexSearchable': True,
#    'moduleConfig': {'text2vec-openai': {'skip': False,
#      'vectorizePropertyName': False}},
#    'name': 'date',
#    'tokenization': 'word'},
#   {'dataType': ['text'],
#    'indexFilterable': True,
#    'indexSearchable': True,
#    'moduleConfig': {'text2vec-openai': {'skip': False,
#      'vectorizePropertyName': False}},
#    'name': 'url',
#    'tokenization': 'word'},
#   {'dataType': ['text'],
#    'indexFilterable': True,
#    'indexSearchable': True,
#    'moduleConfig': {'text2vec-openai': {'skip': False,
#      'vectorizePropertyName': False}},
#    'name': 'tags',
#    'tokenization': 'word'},
#   {'dataType': ['text'],
#    'indexFilterable': True,
#    'indexSearchable': True,
#    'moduleConfig': {'text2vec-openai': {'skip': False,
#      'vectorizePropertyName': False}},
#    'name': 'upload_note',
#    'tokenization': 'word'}],
#  'replicationConfig': {'factor': 1},
#  'shardingConfig': {'virtualPerPhysical': 128,
#   'desiredCount': 1,
#   'actualCount': 1,
#   'desiredVirtualCount': 128,
#   'actualVirtualCount': 128,
#   'key': '_id',
#   'strategy': 'hash',
#   'function': 'murmur3'},
#  'vectorIndexConfig': {'skip': False,
#   'cleanupIntervalSeconds': 300,
#   'maxConnections': 64,
#   'efConstruction': 128,
#   'ef': -1,
#   'dynamicEfMin': 100,
#   'dynamicEfMax': 500,
#   'dynamicEfFactor': 8,
#   'vectorCacheMaxObjects': 1000000000000,
#   'flatSearchCutoff': 40000,
#   'distance': 'cosine',
#   'pq': {'enabled': False,
#    'bitCompression': False,
#    'segments': 0,
#    'centroids': 256,
#    'trainingLimit': 100000,
#    'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}}},
#  'vectorIndexType': 'hnsw',
#  'vectorizer': 'text2vec-openai'}

# %% [markdown]
# ## Ingest document data using Unstructured
# Unstructured allows essentially any file to be uploaded and text data extracted. Testing on documents in `../data/`.

# %%
doc_elements = partition("../data/Politics and the English Language - George Orwell.pdf")
data_objects = stage_for_weaviate(doc_elements)

for key in ['filename', 'file_directory', 'filetype', 'page_number', 'text', 'category']:
    print("{0}: {1}".format(key, data_objects[0][key]))
# Out:
# filename: Politics and the English Language - George Orwell.pdf
# file_directory: ../data
# filetype: application/pdf
# page_number: 1
# text: Politics and the English Language - George Orwell
# category: Title

# %%
data_objects[0].keys()
# Out:
# dict_keys(['filetype', 'page_number', 'text', 'category'])

# %% [markdown]
# Not sure how much of the above data actually needs to be stored. Store it all for now, but there's likely more interesting metadata to be added here. Examples might be a sentiment analysis score, GPT-generated summary, external links and internal links, etc.
#
# Upload to Weaviate with the uploaded data fitting the defined schema:

# %%
# show the first data object of UncategorizedTest 
data_objects[0]['text']
# Out:
# "Indigenous community's handling of COVID shows why Voice to Parliament needed, Fiona Stanley says"

# %%
upload_note = "Fiona Stanley praises the Aboriginal response to COVID-19, calling it the best in the world and a strong argument for an Indigenous Voice to Parliament. She highlighted that contrary to expectations, there were significantly fewer COVID-19 cases among Indigenous Australians compared to their non-Indigenous counterparts at the start of the pandemic. Stanley attributes this success to the high level of input and self-determination in health responses during the pandemic, stating that the Aboriginal response is the best example of why a Voice is going to make such a difference."
tags = "voice to parliament, covid-19"


with client.batch(batch_size=10) as batch:
    for i, d in enumerate(data_objects):  
        properties = {
            'category': d['category'],
            'text': d['text'],
            'article_name' : data_objects[0]['text'],
            'url': article_url,
            'filetype': d['filetype'],
            'date': date.today().strftime("%Y-%m-%d"),
            'upload_note': upload_note, # testing
            'tags': tags # testing
        }
        batch.add_data_object(
            properties,
            'ABCNewsArticle',
            uuid=generate_uuid5(properties),
        )

# %% [markdown]
# ## Querying Weaviate
# Once the data is in Weaviate, a NearText search (to research) can be performed to find concepts similar to user input:

# %%
nearText = {"concepts": ["renters", "cost of living"]}

client = weaviate.Client(
    url=weaviate_url,
    auth_client_secret=weaviate.AuthApiKey(api_key=weaviate_api_key),
    additional_headers= {
        "X-OpenAI-Api-Key": openai_api_key,
    }
)


response = (
    client.query  # start a new query
    .get("ABCNewsArticle", ["text", "article_name", "upload_note", "tags"])  # get objects of the "UnstructuredDocument" class and retrieve their "text" property
    .with_near_text(nearText)  # find objects that are semantically similar to the text in "nearText"
    .with_limit(6)  # limit the results to the top 2 most similar objects
    #.with_where({
    #    "path": ["tags"],
    #    "operator": "Equal",
    #    "valueString": "updatedtest"
    #})
    .do()  # execute the query
)

# %%
client = weaviate.Client(
    url=weaviate_url,
    auth_client_secret=weaviate.AuthApiKey(api_key=weaviate_api_key),
    additional_headers= {
        "X-OpenAI-Api-Key": openai_api_key,
    }
)

response = (
    client.query  # start a new query
    .get("ABCNewsArticle", ["text", "article_name", "category"])  # limit the results to the top 2 most similar objects
    .with_where({
        "path": ["tags"],
        "operator": "Equal",
        "valueString": "test"
    })
    .do()  # execute the query
)

# %%
# extract text from response
print("title: " + response['data']['Get']['ABCNewsArticle'][0]['text'])
for i, r in enumerate(response['data']['Get']['ABCNewsArticle']):
    print("\ncategory: {0}\ncontent: {1}"
    .format(r['category'], r['text']))
# Out:
# title: Former Australian of the Year Fiona Stanley believes Aboriginal people had the best response to COVID-19 "in the world", and says it proves an Indigenous Voice to Parliament will improve health outcomes for First Nations people.
#
# category: NarrativeText
# content: Former Australian of the Year Fiona Stanley believes Aboriginal people had the best response to COVID-19 "in the world", and says it proves an Indigenous Voice to Parliament will improve health outcomes for First Nations people.
#
# category: UncategorizedText
# content: Indigenous community's handling of COVID shows why Voice to Parliament needed, Fiona Stanley says
#
# category: NarrativeText
# content: Help keep family & friends informed by sharing this article
#
# category: Title
# content: Copy link
#
# category: NarrativeText
# content: Link copied
#
# category: Title
# content: By Daryna Zadvirna
#
# category: Title
# content: abc.net.au/news/covid-response-shows-indigenous-voice-needed-fiona-stanley-says/102582244
#
# category: Title
# content: ABC News: Daryna Zadvirna)
#
# category: NarrativeText
# content: Speaking at a panel discussion in support of the Voice on Monday evening, the epidemiologist noted for her public health work, said there was evidence showing the Voice referendum would make a significant difference to Indigenous people's lives.
#
# category: NarrativeText
# content: "We would have anticipated because of the high risks of Aboriginal people — chronic disease, overcrowded conditions, and most Aboriginal people actually live in cities, only 18 per cent live in remote communities – they were of high risk [of contracting the virus]," she said.
#
# category: ListItem
# content: She says their pandemic response shows a Voice will make a difference
#
# category: Title
# content: Key points:
#
# category: ListItem
# content: Fiona Stanley says Indigenous people benefited from having a say on COVID
#
# category: ListItem
# content: But debate continues over the Voice, with critics saying it remains confusing
#
# category: NarrativeText
# content: "They had a Voice in the National Aboriginal Community Controlled Health Organisation. They had a Voice at all state and territory organisations right down to communities."
#
# category: NarrativeText
# content: "Well, within the first 18 to 20 months of the pandemic, Aboriginal people had six times fewer cases than non-Indigenous people did. How did they do it? They had a voice.
#
# category: NarrativeText
# content: Professor Stanley said contrary to expectation, there were significantly fewer COVID-19 cases among Indigenous Australians compared to their non-Indigenous counterparts at the start of the pandemic.
#
# category: NarrativeText
# content: "We already know the Yes campaign have the hardest job ... to convince Australians that this is something that is worthwhile for the future.
#
# category: NarrativeText
# content: Professor Stanley was a panellist at the pro-Voice event, along with former High Court chief justice Robert French and author Thomas Mayo.
#
# category: Title
# content: Debate reminiscent of Mabo: Dorinda Cox
#
# category: NarrativeText
# content: Professor Stanley told the event in Perth that the relatively small number of COVID-19 cases among Indigenous Australians was the result of the high level of input and self-determination in health responses during the pandemic.
#
# category: NarrativeText
# content: She echoed concerns raised by former WA Aboriginal affairs minister Ben Wyatt that the state's controversial new Aboriginal heritage laws were being used as a weapon against the referendum.
#
# category: NarrativeText
# content: "The Aboriginal response to the pandemic was the best in the world," she said.
#
# category: NarrativeText
# content: "And it is the best example of why a Voice is going to make such a difference."
#
# category: NarrativeText
# content: Speaking earlier on Monday at a media event in Perth as part of the Yes campaign, WA senator Dorinda Cox said attempts to use new heritage laws as a tool to oppose the Voice were reminiscent of Australians being warned they would "lose their backyards" over the Mabo decision.
#
# category: NarrativeText
# content: "I think what needs to be stopped is the scaremongering and putting those two things together [is] enabling a conversation that is destructive," Senator Cox said.
#
# category: NarrativeText
# content: The Voice would be an independent body advising parliament and government about matters that affect the lives of Aboriginal and Torres Strait Islander Australians.
#
# category: NarrativeText
# content: Federal MP for Perth Patrick Gorman said constitutional recognition was more significant for West Australians than the GST.
#
# category: Title
# content: ABC News)
#
# category: NarrativeText
# content: "This is bigger than the GST because it is about something for the next generation, it's about bringing people together, it's about closing that gap that for too long we have not been able to close in doing things the same way year in, year out."
#
# category: NarrativeText
# content: What is the Voice to Parliament?We break down everything to do with the Indigenous Voice to Parliament referendum.Read more
#
# category: NarrativeText
# content: Australians will vote later this year on whether or not to enshrine an Indigenous Voice to Parliament in the constitution.
#
# category: NarrativeText
# content: Loading YouTube content
#
# category: NarrativeText
# content: "I think putting those two things together is what we saw in the days of the Mabo decision, that people would lose their backyards. And we don't want to go back to that, that's part of history.
#
# category: Title
# content: Bigger for WA than GST, declares Patrick Gorman
#
# category: NarrativeText
# content: "What we want to do is look forward to what we see as a reconciled Australia."
#
# category: NarrativeText
# content: In a sign of how crucial WA's vote is in the referendum, Indigenous Affairs Minister Linda Burney will on Monday begin a tour of regional WA to drum up support for the change.
#
# category: NarrativeText
# content: Indigenous activist Megan Krakouer is firmly in the No camp, and believes the Voice does not go far enough to achieve social reform.
#
# category: NarrativeText
# content: Ms Krakouer labelled comments on the heritage laws as a distraction that muddied the waters around the Voice proposal.
#
# category: Title
# content: ABC News: Briana Shepherd)
#
# category: NarrativeText
# content: It would only provide advice and would have no authority to overrule parliament.
#
# category: NarrativeText
# content: "I want to see something that has teeth in it, that can actually compel the social reforms that are much needed," she said.
#
# category: NarrativeText
# content: Some common suggestions in opposition to the Voice were that it would be divisive, that the proposal lacks clarity, and it would not have any real impact.
#
# category: Title
# content: Voice has no 'teeth', No campaigner says
#
# category: NarrativeText
# content: "There's enough confusion as to what the Voice means at this point and what it looks like," she said.
#
# category: NarrativeText
# content: "I have people saying, 'I don't know what the Voice is, is that John Farnham The Voice, is that the TV show The Voice?'"
#
# category: NarrativeText
# content: updated
#
# category: Title
# content: Loading...
#
# category: NarrativeText
# content: If you're unable to load the form, you can access it here.
#
# category: ListItem
# content: 'Systemic failure': WA youth detainees 'unlawfully confined' during lockdowns, court finds
#
# category: UncategorizedText
# content: Select "Western Australia Top Stories" from either the ABC News homepage or the settings menu in the app.
#
# category: Title
# content: Want more local WA news?
#
# category: ListItem
# content: Clancy the blue heeler survives a week in the bush after car rollover in remote WA
#
# category: ListItem
# content: Perth punching above its weight in competitive world of cycling, and proof is found at Tour de France
#
# category: Title
# content: Posted
#
# category: NarrativeText
# content: Here's some of the latest local reads from WA 📰
#
# category: Title
# content: More on:
#
# category: ListItem
# content:
#
# category: ListItem
# content: Facebook
#
# category: ListItem
# content: These advocates are voting differently on the Voice — they want you to know why
#
# category: ListItem
# content: Voice to Parliament 'damaging in the long term', former PM Tony Abbott says
#
# category: Title
# content: Related Stories
#
# category: ListItem
# content: Copy link
#
# category: ListItem
# content: Twitter
#
# category: Title
# content: Share
#
# category: ListItem
# content: WA recorded more 'no' votes than anywhere else in 1967 referendum, could 'myths' on the Voice see it happen again?
#
# category: ListItem
# content: 'She is not the victim here': Woman to be released from prison after pleading guilty to manslaughter of partner in violent fight
#
# category: ListItem
# content: Perth
#
# category: ListItem
# content: Aboriginal
#
# category: ListItem
# content: Referendums
#
# category: ListItem
# content: Work-from-home deal 'groundbreaking', but business groups warn of CBD 'death knell'
#
# category: ListItem
# content: Indigenous (Aboriginal and Torres Strait Islander)
#
# category: ListItem
# content: Indigenous Policy
#
# category: ListItem
# content: Government and Politics
#
# category: ListItem
# content: Young renters under most strain, but full mortgage pain yet to be felt, warns CBA boss
#
# category: ListItem
# content: Elon Musk, who has warned of AI's potential for 'civilisational destruction', launches own AI startup
#
# category: ListItem
# content: NASA's 'chaotic' new image reveals detail undetectable to the human eye
#
# category: ListItem
# content: Actor Vince Colosimo has tens of thousands in traffic fines wiped by court
#
# category: ListItem
# content: Zayn Malik opens up about One Direction departure in first interview in six years
#
# category: ListItem
# content: Russian general dismissed after accusing top officers of betraying soldiers
#
# category: ListItem
# content: AFL live: Swans seeking a boost against Bulldogs at SCG
#
# category: ListItem
# content: Ben Roberts-Smith judge accused of 'cherry-picking' evidence as war veteran's lawyers launch appeal
#
# category: ListItem
# content: After she was covered in hot volcanic ash, travel blogger Annie endured a horrifying journey to get help
#
# category: ListItem
# content: Rapper The Kid LAROI sponsors outback footy club's Indigenous guernsey
#
# category: ListItem
# content: Future Matildas to take football to 'next level' ahead of Women's World Cup
#
# category: UncategorizedText
# content: 4.
#
# category: ListItem
# content: Mum-of-10 forced to cut back on school lunches as food prices 'out of control'
#
# category: Title
# content: Popular Now
#
# category: UncategorizedText
# content: Actor Vince Colosimo has tens of thousands in traffic fines wiped by court
#
# category: Title
# content: Work-from-home deal 'groundbreaking', but business groups warn of CBD 'death knell'
#
# category: UncategorizedText
# content: 2.
#
# category: UncategorizedText
# content: 3.
#
# category: Title
# content: Russian general dismissed after accusing top officers of betraying soldiers
#
# category: UncategorizedText
# content: 1.
#
# category: ListItem
# content: Battery eggs on the way out — eventually — as ministers agree they have to go
#
# category: NarrativeText
# content: Russian general dismissed after accusing top officers of betraying soldiers
#
# category: UncategorizedText
# content: 5.
#
# category: NarrativeText
# content: Work-from-home deal 'groundbreaking', but business groups warn of CBD 'death knell'
#
# category: UncategorizedText
# content: After she was covered in hot volcanic ash, travel blogger Annie endured a horrifying journey to get help
#
# category: UncategorizedText
# content: 'She is not the victim here': Woman to be released from prison after pleading guilty to manslaughter of partner in violent fight
